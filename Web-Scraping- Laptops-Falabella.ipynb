# %% [markdown]
# # <center><h1><b>Web Scraping de datos de Laptops de la página de Falabella</b></h1></center>

# %%
#Importamos las librerias necesarias para poder hacer web-scraping

from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By

#Importamos pandas para trabajar con DataFrames
import pandas as pd

# %% [markdown]
# ### <center><h1><b>Accediendo a datos por partes</b></h1></center>

# %% [markdown]
# # Los datos que vamos a extraer son los siguientes:
#
# * Nombre
# * Precio con descuento
# * Precio (Actual)
# * Precio anterior
#
#
# ![lap.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1: Extracción de valores (Nombre de las laptops)

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops") 

#Creamos una lista vacía donde se almacenará los datos obtenidos
nombres_productos = []



# Extraccion de nombres
    ## Iteramos para poder extraer mas datos, en este caso los 9 primeros productos
    
for i in range(1,10):  
    
    #Esta direccion lo obtenemos de ponernos sobre el nombre del producto e inspeccionamos el elemento
    # y copiamos el  X_path completo
    
    # Hacemos que itere para poder acceder a mas datos,  usando format(i) en {}
    x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/div[2]/a/span[1]".format(i)
    
    #Los datos obtenidos lo agregamos  la lista "nombres_productos" previamente creada
    nombres_productos.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista

# %%
#Mostramos los datos de la lista
nombres_productos
# Out:
# ['Laptop Gamer Asus TUF A15 R7...',
#  'Laptop Gamer ACER Nitro Intel Core i7...',
#  'Laptop HP Pavilion Intel Core i5 11°...',
#  'Laptop ASUS Intel Core i5 11° Gen...',
#  'Laptop Lenovo Yoga Slim 7 Pro Intel...',
#  'Laptop Gamer ASUS TUF Dash F15 Intel...',
#  'Laptop Gamer Ideapad 3 Amd...',
#  'Laptop Hp Pavilion Plus 14-Eh0102La...',
#  'Laptop HP OPP AMD Ryzen 7...']

# %%
#vemos la cantidad de datos de la lista
len(nombres_productos)
# Out:
# 9

# %% [markdown]
# ## 2: Extracción de valores de los precios con descuento de las laptops

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops") 
            
#Creamos una lista vacía donde se almacenará los datos obtenidos
precios_productos_descuento = []


# Extraccion de nombres
    ## Iteramos para poder extraer mas datos, en este caso los 9 primeros productos
for i in range(1,10):  

    try:
    #Esta direccion lo obtenemos de ponernos sobre el precio con descuento del producto y inspeccionamos el elemento
    # y copiamos el  X_path completo
    
        # Hacemos que itere para poder acceder a mas datos,  usando format(i) en {}
        x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[1]/div/span".format(i)           
       
        #Los datos obtenidos lo agregamos  la lista "precios_productos_descuento" previamente creada
        precios_productos_descuento.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 

    except:
        
        #En caso no existe este dato lo completa con "-"
        precios_productos_descuento.append("-")

# %%
#Mostramos los datos de la lista
precios_productos_descuento
# Out:
# ['S/ 4,699',
#  'S/ 6,999',
#  'S/ 2,299',
#  'S/ 1,899',
#  'S/ 1,999',
#  'S/ 3,399',
#  'S/ 2,899',
#  'S/ 4,499',
#  'S/ 2,599']

# %%
#vemos la cantidad de datos de la lista
len(precios_productos_descuento)
# Out:
# 9

# %% [markdown]
# ## 3: Extracción de valores de los precios de las laptops

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops") 

#Creamos una lista vacía donde se almacenará los datos obtenidos
precios_productos = []

# Extraccion de Precios
#iteramos para poder extraer mas datos, en este caso los 9 primeros productos
for i in range(1,10):  
    
    try : 
        
        #Esta direccion lo obtenemos de ponernos sobre el precio del producto y inspeccionamos el elemento
        # y copiamos el  X_path completo
    
        # Hacemos que itere para poder acceder a mas datos,  usando format(i) en {}
        x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[2]/div/span".format(i)        
       
        #Los datos obtenidos lo agregamos  la lista "precios_productos" previamente creada
        precios_productos.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 
        
    except:
        precios_productos.append("-")

# %%
#Mostramos los datos de la lista
precios_productos
# Out:
# ['S/ 2,999',
#  'S/ 1,999',
#  'S/ 4,799',
#  'S/ 8,799',
#  'S/ 2,099',
#  'S/ 3,599',
#  'S/ 2,999',
#  'S/ 4,599',
#  'S/ 3,699']

# %%
#vemos la cantidad de datos de la lista
len(precios_productos)
# Out:
# 9

# %% [markdown]
# ## 4: Extracción de valores de los anteriores precios de las laptops

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops") 

#Creamos una lista vacía donde se almacenará los datos obtenidos
precios_3 = []

# Extraccion de Precios
#iteramos para poder extraer mas datos, en este caso los 9 primeros productos
for i in range(1,10):  
    
    try : 
        
        #Esta direccion lo obtenemos de ponernos sobre el precio 3 y inspeccionamos el elemento
        # y copiamos el  X_path completo
    
        # Hacemos que itere para poder acceder a mas datos,  usando format(i) en {}
        x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[3]/div/span".format(i)        
        
        precios_3.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 
        
    except:
        precios_3.append("-")

# %%
#Mostramos los datos de la lista
precios_3
# Out:
# ['S/ 5,999',
#  '-',
#  '-',
#  'S/ 2,799',
#  'S/ 2,299',
#  'S/ 4,899',
#  'S/ 4,499',
#  'S/ 5,799',
#  '-']

# %%
#vemos la cantidad de datos de la lista
len(precios_3)
# Out:
# 9

# %% [markdown]
# ## 5: Código para hacer click  y pasar a la siguiente página

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops")

#Esta direccion lo obtenemos de ponernos sobre el el botóm para pasar página y inspeccionamos el elemento
# y copiamos el  X_path completo

x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[4]/div[2]/div/button"
driver.find_elements(By.XPATH, value = x_path)[0].click()

# %% [markdown]
# ## <center><h1><b>Extracción de datos todo en uno</b></h1></center>

# %%
# Accedemos a la ruta del  DRIVER previamente descargados y descomprimido
driver = webdriver.Chrome("C:/Users/Usuario/Downloads/chromedriver_win32/chromedriver.exe")

#le pasamos la url de la pagina a scrapear
driver.get("https://www.falabella.com.pe/falabella-pe/category/cat40712/Laptops") 

#Creamos listas vacía donde se almacenarán los datos obtenidos
nombres_productos = []
precios_productos = []
precios_productos_descuento = []
precios_3 = []

#creamos un contador cuantas veces debe pasar de página
contador = 0


while contador <2:
    for i in range(1,30):  
            #1
            x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/div[2]/a/span[1]".format(i)
            nombres_productos.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 

            
            #2----------------------------------------------------------
            try:
                x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[1]/div/span".format(i)           
                precios_productos_descuento.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 

            except:
                precios_productos_descuento.append("-") 
                
                
            #3 --------------------------------------------------------------
            try :
                x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[2]/div/span".format(i)                  
                precios_productos.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 
            
            except:
                precios_productos.append("-")


            #4 ----------------------------------------------------------
            try : 
                x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[3]/div[{}]/div/a/div[1]/ol/li[3]/div/span".format(i)        
                precios_3.append(driver.find_elements(By.XPATH, value = x_path)[0].text)   #esto es una lista 
            except:
                precios_3.append("-")
                
                
    #5 codigo para pasar de página            
    x_path = "//html/body/div[1]/div/div[2]/div[2]/section[2]/div/div[1]/div/div[2]/div/div/button"
               
    driver.find_elements(By.XPATH, value = x_path)[0].click()
    contador = contador + 1

# %% [markdown]
# ## CREAMOS DATAFRAME CON LAS LISTAS CREADAS DE PRODUCTO Y PRECIO

# %%
import numpy as np

data = pd.DataFrame(nombres_productos , columns = ["Productos"])
data["Precio con descuento"] = precios_productos_descuento
data["Precio"] = precios_productos
data["Precio Anterior"] = precios_3

# %%
data
# Out:
#                                     Productos Precio con descuento  \
# 0             Laptop Gamer Asus TUF A15 R7...             S/ 4,699
# 1    Laptop Gamer ACER Nitro Intel Core i7...             S/ 6,999
# 2     Laptop HP Pavilion Intel Core i5 11°...             S/ 2,299
# 3        Laptop ASUS Intel Core i5 11° Gen...             S/ 1,899
# 4      Laptop Lenovo Yoga Slim 7 Pro Intel...             S/ 1,999
# 5     Laptop Gamer ASUS TUF Dash F15 Intel...             S/ 3,399
# 6               Laptop Gamer Ideapad 3 Amd...             S/ 2,899
# 7      Laptop Hp Pavilion Plus 14-Eh0102La...             S/ 4,499
# 8                Laptop HP OPP AMD Ryzen 7...             S/ 2,599
# 9        Laptop ASUS Intel Core i5 10° Gen...             S/ 1,699
# 10          Laptop Lenovo IdeaPad 3i Intel...             S/ 1,599
# 11                 Aspire 3 CI3 1005G1 8GB...             S/ 1,299
# 12         Laptop Gamer ASUS Intel Core i5...             S/ 2,999
# 13          Laptop Lenovo IdeaPad 5i Intel...             S/ 2,499
# 14          Bundle HP Laptop 15-dy5010la +...             S/ 3,399
# 15              Laptop Gamer Ideapad 3 Amd...             S/ 2,899
# 16             Laptop Gamer LENOVO Ideapad...             S/ 2,999
# 17               Laptop HP OPP AMD Ryzen 5...             S/ 1,899
# 18             Laptop Gamer LENOVO Ideapad...             S/ 4,199
# 19            Laptop AMD Ryzen 5 7520U 8Gb...             S/ 1,899
# 20         LENOVO V15 Intel Core i3-10110U...             S/ 1,249
# 21   Laptop Gamer ACER Nitro Intel Core i5...             S/ 3,599
# 22     Laptop Gamer ASUS TUF Intel Core i7...             S/ 4,599
# 23          Laptop HP Pavilion 15-EG0501lA...             S/ 2,399
# 24    Laptop Gamer HP Victus Intel Core i5...             S/ 2,799
# 25             Laptop Gamer LENOVO Ideapad...             S/ 3,299
# 26      Laptop DELL Vostro 14" AMD Ryzen 5...             S/ 1,259
# 27       Macbook Air 13 pulgadas - Chip M1...             S/ 4,299
# 28        Aspire 3 CI5 1235U 8GB 256GB SSD...             S/ 2,499
# 29    Laptop HP Pavilion Intel Core i5 11°...                    -
# 30       Laptop Convertible Lenovo Ideapad...             S/ 1,398
# 31            Laptop Gamer Asus TUF A15 R7...             S/ 4,699
# 32   Laptop Gamer ACER Nitro Intel Core i7...             S/ 6,999
# 33                  Laptop ASUS Zenbook 14...             S/ 4,599
# 34                IdeaPad Duet Chromebook ...               S/ 849
# 35              Laptop Gamer Ideapad 3 Amd...             S/ 2,899
# 36     Laptop Hp Pavilion Plus 14-Eh0102La...             S/ 4,499
# 37                 Laptop ASUS Vivobook 15...             S/ 3,299
# 38                Laptop Gamer TUF A15 AMD...             S/ 4,099
# 39             Laptop Hp 15-Dy2059La Intel...             S/ 1,749
# 40              Laptop HP EliteBook 840 G3...             S/ 1,200
# 41            Laptop Advance NV6650 14pulg...            S/ 629.90
# 42  Laptop ACER Aspire 3 Intel Core i5 12°...             S/ 2,299
# 43               Laptop HP 15 ef2501la AMD...             S/ 2,449
# 44               Chromebook LENOVO Ideapad...             S/ 1,699
# 45        Laptop Ideapad Gaming Intel Core...             S/ 2,899
# 46              Laptop LENOVO Ideapad D330...             S/ 1,799
# 47           Notebook Acer Swift 3 Ryzen 7...             S/ 4,299
# 48    Laptop Gamer HP Victus Intel Core i5...             S/ 3,999
# 49              Laptop Gamer Asus TUF Dash...             S/ 3,499
# 50               LAPTOP CHUWI HEROBOOK PRO...               S/ 638
# 51            Laptop Gamer LENOVO Legion 5...             S/ 3,499
# 52                  CHROMEBOOK S330 LENOVO...               S/ 549
# 53    Portátil ASUS X515 Intel Core i5 10°...             S/ 1,799
# 54             Laptop Gamer LENOVO Ideapad...             S/ 4,699
# 55              Laptop HP 15.6" Intel Core...          S/ 2,489.99
# 56         Laptop DELL Ryzen 5 Ram 8GB SSD...             S/ 2,190
# 57        Aspire 3 CI5 1235U 8GB 256GB SSD...             S/ 2,499
#
#          Precio Precio Anterior
# 0      S/ 4,799        S/ 5,999
# 1      S/ 8,799               -
# 2      S/ 2,999               -
# 3      S/ 1,999        S/ 2,799
# 4      S/ 2,099        S/ 2,299
# 5      S/ 3,599        S/ 4,899
# 6      S/ 2,999        S/ 4,499
# 7      S/ 4,599        S/ 5,799
# 8      S/ 3,699               -
# 9      S/ 1,799        S/ 3,299
# 10     S/ 2,599               -
# 11     S/ 1,399        S/ 1,999
# 12     S/ 3,099        S/ 4,299
# 13     S/ 2,599               -
# 14     S/ 3,499               -
# 15     S/ 2,999        S/ 4,499
# 16     S/ 4,599               -
# 17     S/ 1,959        S/ 2,799
# 18     S/ 6,899               -
# 19     S/ 1,999        S/ 2,229
# 20     S/ 1,359        S/ 1,600
# 21     S/ 4,699               -
# 22     S/ 4,699        S/ 5,999
# 23            -               -
# 24     S/ 3,899               -
# 25     S/ 5,199               -
# 26     S/ 1,369        S/ 1,779
# 27     S/ 5,799               -
# 28     S/ 3,499               -
# 29     S/ 2,099               -
# 30            -               -
# 31     S/ 4,799        S/ 5,999
# 32     S/ 8,799               -
# 33     S/ 5,699               -
# 34     S/ 1,799               -
# 35     S/ 2,999        S/ 4,499
# 36     S/ 4,599        S/ 5,799
# 37     S/ 4,199               -
# 38     S/ 4,199        S/ 4,499
# 39     S/ 1,769        S/ 2,099
# 40            -               -
# 41       S/ 700               -
# 42     S/ 3,299               -
# 43     S/ 2,469        S/ 2,699
# 44     S/ 1,999               -
# 45     S/ 3,999               -
# 46            -               -
# 47            -               -
# 48     S/ 4,099        S/ 4,699
# 49     S/ 3,599        S/ 4,599
# 50       S/ 899               -
# 51     S/ 4,999               -
# 52       S/ 999               -
# 53     S/ 3,199               -
# 54     S/ 6,499               -
# 55  S/ 3,999.99               -
# 56     S/ 2,700               -
# 57     S/ 3,499               -
